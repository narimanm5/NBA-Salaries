# %%
import pandas as pd

# %%
stats_df = pd.read_csv("Seasons_Stats.csv")

# %%
stats_df
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# ...           ...     ...                ...  ...   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV  \
# ...

# %%
stats_df.shape
# Out:
# (24691, 53)

# %%
filt = (stats_df["Year"] == 2017.0) | (stats_df["Year"] == 2018.0) 
df = stats_df.loc[filt].sort_values("Player").reset_index()
df.drop("Unnamed: 0",inplace=True,axis = 1)
df.index += 1
df.drop("index",inplace=True,axis = 1)

# %%
df
# Out:
#        Year          Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 1    2017.0    A.J. Hammons   C  24.0  DAL  22.0   0.0   163.0   8.4  0.472
# 2    2017.0    Aaron Brooks  PG  32.0  IND  65.0   0.0   894.0   9.5  0.507
# 3    2017.0    Aaron Gordon  SF  21.0  ORL  80.0  72.0  2298.0  14.4  0.530
# 4    2017.0  Aaron Harrison  SG  22.0  CHO   5.0   0.0    17.0  -2.2  0.102
# 5    2017.0   Adreian Payne  PF  25.0  MIN  18.0   0.0   135.0  14.4  0.505
# ..      ...             ...  ..   ...  ...   ...   ...     ...   ...    ...
# 591  2017.0    Yogi Ferrell  PG  23.0  DAL  36.0  29.0  1046.0  14.1  0.541
# 592  2017.0    Yogi Ferrell  PG  23.0  TOT  46.0  29.0  1197.0  13.1  0.533
# 593  2017.0     Zach LaVine  SG  21.0  MIN  47.0  47.0  1749.0  14.6  0.576
# 594  2017.0   Zach Randolph  PF  35.0  MEM  73.0   5.0  1786.0  18.5  0.490
# 595  2017.0   Zaza Pachulia   C  32.0  GSW  70.0  70.0  1268.0  16.1  0.588
#
# ...

# %%
salaries = pd.read_csv("NBA_season1718_salary.csv")

# %%
salaries.sort_values("Player",inplace = True)
salaries.drop("Unnamed: 0",inplace=True,axis = 1)
salaries.reset_index(inplace = True)
salaries.index += 1
salaries.drop("index",inplace=True,axis = 1)
salaries
# Out:
#             Player   Tm  season17_18
# 1     A.J. Hammons  MIA    1312611.0
# 2     Aaron Brooks  MIN    2116955.0
# 3     Aaron Gordon  ORL    5504420.0
# 4       Aaron Gray  DET     452059.0
# 5      Abdel Nader  BOS    1167333.0
# ..             ...  ...          ...
# 569   Zach Collins  POR    3057240.0
# 570    Zach LaVine  CHI    3202217.0
# 571  Zach Randolph  SAC   12307692.0
# 572  Zaza Pachulia  GSW    3477600.0
# 573        Zhou Qi  HOU     815615.0
#
# [573 rows x 3 columns]

# %%
for i in range(len(salaries)):
    if salaries.loc[i+1,"Player"] not in df["Player"]:
        print(salaries.loc[i+1,"Player"])
    else:
        print(1)
# Out:
# A.J. Hammons
# Aaron Brooks
# Aaron Gordon
# Aaron Gray
# Abdel Nader
# Al Horford
# Al Jefferson
# Al-Farouq Aminu
# Alan Williams
# Alec Burks
# Alex Abrines
# Alex Len
# Alex Poythress
# Alexis Ajinca
# Alfonzo McKinnie
# Allen Crabbe
# Amir Johnson
# Anderson Varejao
# Andre Drummond
# Andre Iguodala
# Andre Roberson
# Andrew Bogut
# Andrew Harrison
# Andrew Nicholson
# Andrew Wiggins
# Ante Zizic
# Anthony Davis
# Anthony Tolliver
# Anthony Tolliver
# Antonius Cleveland
# Antonius Cleveland
# Aron Baynes
# Arron Afflalo
# Arron Afflalo
# Austin Rivers
# Avery Bradley
# Axel Toupane
# Bam Adebayo
# Ben McLemore
# Ben Simmons
# Beno Udrih
# Bismack Biyombo
# Blake Griffin
# Boban Marjanovic
# Bobby Brown
# Bobby Portis
# Bogdan Bogdanovic
# Bojan Bogdanovic
# Bradley Beal
# Brandan Wright
# Brandon Ingram
# Brandon Jennings
# Brandon Knight
# Brandon Paul
# Brandon Rush
# Briante Weber
# Briante Weber
# Briante Weber
# Brice Johnson
# Brook Lopez
# Bruno Caboclo
# Bryn Forbes
# ...

# %%
dups = df.duplicated(subset=['Player'],keep=False)
duplicates = df[dups]
filt = duplicates["Tm"] == "TOT"
dups1 = duplicates[filt]

# %%
df.drop_duplicates(subset=['Player'],keep=False,inplace=True)
df = pd.concat([df,dups1])
df = df.sort_values("Player").reset_index()

# %%
salaries = salaries.groupby('Player')['season17_18'].sum().reset_index()
salaries
# Out:
#             Player  season17_18
# 0     A.J. Hammons    1312611.0
# 1     Aaron Brooks    2116955.0
# 2     Aaron Gordon    5504420.0
# 3       Aaron Gray     452059.0
# 4      Abdel Nader    1167333.0
# ..             ...          ...
# 530   Zach Collins    3057240.0
# 531    Zach LaVine    3202217.0
# 532  Zach Randolph   12307692.0
# 533  Zaza Pachulia    3477600.0
# 534        Zhou Qi     815615.0
#
# [535 rows x 2 columns]

# %%
dups = salaries.duplicated(subset=['Player'],keep=False)
salaries[dups]
# Out:
# Empty DataFrame
# Columns: [Player, season17_18]
# Index: []

# %%
stats = df

# %%
salaries
# Out:
#             Player  season17_18
# 0     A.J. Hammons    1312611.0
# 1     Aaron Brooks    2116955.0
# 2     Aaron Gordon    5504420.0
# 3       Aaron Gray     452059.0
# 4      Abdel Nader    1167333.0
# ..             ...          ...
# 530   Zach Collins    3057240.0
# 531    Zach LaVine    3202217.0
# 532  Zach Randolph   12307692.0
# 533  Zaza Pachulia    3477600.0
# 534        Zhou Qi     815615.0
#
# [535 rows x 2 columns]

# %%
len(salaries["Player"].unique())
# Out:
# 535

# %%
len(df["Player"].unique())
# Out:
# 486

# %%
df
# Out:
#        Year          Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 1    2017.0    A.J. Hammons   C  24.0  DAL  22.0   0.0   163.0   8.4  0.472
# 2    2017.0    Aaron Brooks  PG  32.0  IND  65.0   0.0   894.0   9.5  0.507
# 3    2017.0    Aaron Gordon  SF  21.0  ORL  80.0  72.0  2298.0  14.4  0.530
# 4    2017.0  Aaron Harrison  SG  22.0  CHO   5.0   0.0    17.0  -2.2  0.102
# 5    2017.0   Adreian Payne  PF  25.0  MIN  18.0   0.0   135.0  14.4  0.505
# ..      ...             ...  ..   ...  ...   ...   ...     ...   ...    ...
# 591  2017.0    Yogi Ferrell  PG  23.0  DAL  36.0  29.0  1046.0  14.1  0.541
# 592  2017.0    Yogi Ferrell  PG  23.0  TOT  46.0  29.0  1197.0  13.1  0.533
# 593  2017.0     Zach LaVine  SG  21.0  MIN  47.0  47.0  1749.0  14.6  0.576
# 594  2017.0   Zach Randolph  PF  35.0  MEM  73.0   5.0  1786.0  18.5  0.490
# 595  2017.0   Zaza Pachulia   C  32.0  GSW  70.0  70.0  1268.0  16.1  0.588
#
# ...

# %%
stats
# Out:
#      index    Year           Player Pos   Age   Tm     G    GS      MP   PER  \
# 0        1  2017.0     A.J. Hammons   C  24.0  DAL  22.0   0.0   163.0   8.4
# 1        2  2017.0     Aaron Brooks  PG  32.0  IND  65.0   0.0   894.0   9.5
# 2        3  2017.0     Aaron Gordon  SF  21.0  ORL  80.0  72.0  2298.0  14.4
# 3        4  2017.0   Aaron Harrison  SG  22.0  CHO   5.0   0.0    17.0  -2.2
# 4        5  2017.0    Adreian Payne  PF  25.0  MIN  18.0   0.0   135.0  14.4
# ..     ...     ...              ...  ..   ...  ...   ...   ...     ...   ...
# 481    589  2017.0  Wilson Chandler  SF  29.0  DEN  71.0  33.0  2197.0  14.9
# 482    592  2017.0     Yogi Ferrell  PG  23.0  TOT  46.0  29.0  1197.0  13.1
# 483    593  2017.0      Zach LaVine  SG  21.0  MIN  47.0  47.0  1749.0  14.6
# 484    594  2017.0    Zach Randolph  PF  35.0  MEM  73.0   5.0  1786.0  18.5
# 485    595  2017.0    Zaza Pachulia   C  32.0  GSW  70.0  70.0  1268.0  16.1
#
# ...

# %%
merged_df = pd.merge(salaries, stats, on='Player', how='left')

# %%
merged_df.dropna(axis=0,subset="Year",inplace = True)

# %%
merged_df
# Out:
#               Player  season17_18  index    Year Pos   Age   Tm     G    GS  \
# 0       A.J. Hammons    1312611.0    1.0  2017.0   C  24.0  DAL  22.0   0.0
# 1       Aaron Brooks    2116955.0    2.0  2017.0  PG  32.0  IND  65.0   0.0
# 2       Aaron Gordon    5504420.0    3.0  2017.0  SF  21.0  ORL  80.0  72.0
# 5         Al Horford   27734405.0    6.0  2017.0   C  30.0  BOS  68.0  68.0
# 6       Al Jefferson    9769821.0    7.0  2017.0   C  32.0  IND  66.0   1.0
# ..               ...          ...    ...     ...  ..   ...  ...   ...   ...
# 526  Wilson Chandler   12016854.0  589.0  2017.0  SF  29.0  DEN  71.0  33.0
# 529     Yogi Ferrell    1312611.0  592.0  2017.0  PG  23.0  TOT  46.0  29.0
# 531      Zach LaVine    3202217.0  593.0  2017.0  SG  21.0  MIN  47.0  47.0
# 532    Zach Randolph   12307692.0  594.0  2017.0  PF  35.0  MEM  73.0   5.0
# 533    Zaza Pachulia    3477600.0  595.0  2017.0   C  32.0  GSW  70.0  70.0
#
# ...

# %%
merged_df.drop("index",inplace=True,axis = 1)
merged_df.reset_index(inplace = True)
merged_df.index += 1

# %%
merged_df.drop("index",inplace=True,axis = 1)
merged_df
# Out:
#               Player  season17_18    Year Pos   Age   Tm     G    GS      MP  \
# 1       A.J. Hammons    1312611.0  2017.0   C  24.0  DAL  22.0   0.0   163.0
# 2       Aaron Brooks    2116955.0  2017.0  PG  32.0  IND  65.0   0.0   894.0
# 3       Aaron Gordon    5504420.0  2017.0  SF  21.0  ORL  80.0  72.0  2298.0
# 4         Al Horford   27734405.0  2017.0   C  30.0  BOS  68.0  68.0  2193.0
# 5       Al Jefferson    9769821.0  2017.0   C  32.0  IND  66.0   1.0   931.0
# ..               ...          ...     ...  ..   ...  ...   ...   ...     ...
# 407  Wilson Chandler   12016854.0  2017.0  SF  29.0  DEN  71.0  33.0  2197.0
# 408     Yogi Ferrell    1312611.0  2017.0  PG  23.0  TOT  46.0  29.0  1197.0
# 409      Zach LaVine    3202217.0  2017.0  SG  21.0  MIN  47.0  47.0  1749.0
# 410    Zach Randolph   12307692.0  2017.0  PF  35.0  MEM  73.0   5.0  1786.0
# 411    Zaza Pachulia    3477600.0  2017.0   C  32.0  GSW  70.0  70.0  1268.0
#
# ...

# %%
df = merged_df

# %%
df["season17_18"].rename("Salary",inplace=True)
# Out:
# 1       1312611.0
# 2       2116955.0
# 3       5504420.0
# 4      27734405.0
# 5       9769821.0
#           ...
# 407    12016854.0
# 408     1312611.0
# 409     3202217.0
# 410    12307692.0
# 411     3477600.0
# Name: Salary, Length: 411, dtype: float64

# %%
df
# Out:
#               Player  season17_18    Year Pos   Age   Tm     G    GS      MP  \
# 1       A.J. Hammons    1312611.0  2017.0   C  24.0  DAL  22.0   0.0   163.0
# 2       Aaron Brooks    2116955.0  2017.0  PG  32.0  IND  65.0   0.0   894.0
# 3       Aaron Gordon    5504420.0  2017.0  SF  21.0  ORL  80.0  72.0  2298.0
# 4         Al Horford   27734405.0  2017.0   C  30.0  BOS  68.0  68.0  2193.0
# 5       Al Jefferson    9769821.0  2017.0   C  32.0  IND  66.0   1.0   931.0
# ..               ...          ...     ...  ..   ...  ...   ...   ...     ...
# 407  Wilson Chandler   12016854.0  2017.0  SF  29.0  DEN  71.0  33.0  2197.0
# 408     Yogi Ferrell    1312611.0  2017.0  PG  23.0  TOT  46.0  29.0  1197.0
# 409      Zach LaVine    3202217.0  2017.0  SG  21.0  MIN  47.0  47.0  1749.0
# 410    Zach Randolph   12307692.0  2017.0  PF  35.0  MEM  73.0   5.0  1786.0
# 411    Zaza Pachulia    3477600.0  2017.0   C  32.0  GSW  70.0  70.0  1268.0
#
# ...

# %%
df.to_csv("DF.csv")

# %%
df.to_excel("DF.xlsx")
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\LENOVO\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\LENOVO\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\LENOVO\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\LENOVO\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df["PPG"] = df["PTS"]/df['G']
df["MPG"] = df["MP"]/df['G']
df["APG"] = df["AST"]/df['G']
df["RPG"] = df["TRB"]/df['G']
df["TOPG"] = df["TOV"]/df['G']
df["BPG"] = df["BLK"]/df['G']
df["SPG"] = df["STL"]/df['G']

# %%
df
# Out:
#               Player  season17_18    Year Pos   Age   Tm     G    GS      MP  \
# 1       A.J. Hammons    1312611.0  2017.0   C  24.0  DAL  22.0   0.0   163.0
# 2       Aaron Brooks    2116955.0  2017.0  PG  32.0  IND  65.0   0.0   894.0
# 3       Aaron Gordon    5504420.0  2017.0  SF  21.0  ORL  80.0  72.0  2298.0
# 4         Al Horford   27734405.0  2017.0   C  30.0  BOS  68.0  68.0  2193.0
# 5       Al Jefferson    9769821.0  2017.0   C  32.0  IND  66.0   1.0   931.0
# ..               ...          ...     ...  ..   ...  ...   ...   ...     ...
# 407  Wilson Chandler   12016854.0  2017.0  SF  29.0  DEN  71.0  33.0  2197.0
# 408     Yogi Ferrell    1312611.0  2017.0  PG  23.0  TOT  46.0  29.0  1197.0
# 409      Zach LaVine    3202217.0  2017.0  SG  21.0  MIN  47.0  47.0  1749.0
# 410    Zach Randolph   12307692.0  2017.0  PF  35.0  MEM  73.0   5.0  1786.0
# 411    Zaza Pachulia    3477600.0  2017.0   C  32.0  GSW  70.0  70.0  1268.0
#
# ...
